# %% [markdown]
# # Optimize the model

# %% [markdown]
# From the regularization notebook it can be seen that while convolutional layer increases accuracy of training, the model becomes overfit too fast.
#
# The goal of this part of the project is to minimize divergence between validation and training loss while maintaining positive accuracy gradient. Thus, we want accuracy of training & validation to be as close to 1 as possible with validation and training loss being as close to 0 as possible.
#
# To do that, we will use feature-reducing techniques and Data Augmentation.
#
# To reduce features we inroduce Pooling layer after the convolutional layer. Also, instead of using one Conv2D layer with large amount of filters we introduce a sequence of Conv2D layers with smaller amount of filters (also followed by MaxPooling2D)

# %%
# %pip install tensorflow-gpu

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# For data albumentations we can use in-built keras methods, but can also try something different

# %%
import albumentations as alb

# %% [markdown]
# ## Load and pre-process the data

# %%
train_ds, test_ds = tf.keras.datasets.fashion_mnist.load_data()

# %%
val_ds = (train_ds[0][40000:], train_ds[1][40000:])


train_ds = (train_ds[0][:40000], train_ds[1][:40000])

# %%
print(train_ds[0].shape)
print(val_ds[0].shape)
print(test_ds[0].shape)

print(train_ds[1].shape)
print(val_ds[1].shape)
print(test_ds[1].shape)
# Out:
# (40000, 28, 28)
# (20000, 28, 28)
# (10000, 28, 28)
# (40000,)
# (20000,)
# (10000,)

# %%
train_img = train_ds[0]/255
val_img = val_ds[0]/255
test_img = test_ds[0]/255

train_lbl = train_ds[1]
val_lbl = val_ds[1]
test_lbl = test_ds[1]

# %%
idx = []
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

for i in range(25):
    idx.append(np.random.randint(1,len(train_img)))

idx = np.asarray(idx)

fig = plt.figure()

for i in range(len(idx)):
    ax = fig.add_subplot(5,5,i+1)
    ax.imshow(train_img[idx[i]])
    ax.title.set_text(class_names[train_lbl[idx[i]]])
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Define the augmentation pipeline

# %%
transform = alb.Compose([
    alb.HorizontalFlip(p=0.4),
    alb.VerticalFlip(p=0.4),
    alb.Rotate(p=0.4)
    ,alb.Blur(p=0.2, blur_limit=5)
])

# %%
test = train_img[0]
plt.imshow(test)

# %%
fig = plt.figure()

for i in range(9):

    aug_tst = transform(image=test)["image"]

    ax = fig.add_subplot(3,3,i+1)
    ax.imshow(aug_tst)
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout()
plt.show()

# %% [markdown]
# Now we need to apply the augmentation pipeline to the dataset

# %%
# assign datasets to new variables so that the initial are not damaged in case of my miserable failure (backup point)

dummy_train_ds = train_ds
dummy_val_ds = val_ds
dummy_test_ds = test_ds

# %%
# number of augmentations applied to each picture

n_aug = 18

# %%
len(train_ds[0])
# Out:
# 40000

# %%
train_images = [image for image in dummy_train_ds[0]]
train_labels = [label for label in dummy_train_ds[1]]

# %%
np.array(train_images).shape
# Out:
# (40000, 28, 28)

# %%
for img in range(len(train_ds[0])):

    for i in range(n_aug):

        aug_image = transform(image=train_ds[0][img])["image"]
        train_images.append(aug_image)
        train_labels.append(train_ds[1][img])

# %%
shuffle_idx = np.random.permutation(len(train_images))
images_train_augmented = np.array(train_images)[shuffle_idx]
labels_train_augmented = np.array(train_labels)[shuffle_idx]

# %%
images_train_augmented.shape
# Out:
# (760000, 28, 28)

# %%
labels_train_augmented.shape
# Out:
# (760000,)

# %%
idx = []
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

for i in range(25):
    idx.append(np.random.randint(1,len(images_train_augmented)))

idx = np.asarray(idx)

fig = plt.figure()

for i in range(len(idx)):
    ax = fig.add_subplot(5,5,i+1)
    ax.imshow(images_train_augmented[idx[i]])
    ax.title.set_text(class_names[labels_train_augmented[idx[i]]])
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout()
plt.show()

# %%
print((train_ds[0].shape))
print(images_train_augmented.shape)
print(val_img.shape)
# Out:
# (40000, 28, 28)
# (760000, 28, 28)
# (20000, 28, 28)

# %% [markdown]
# Can now use augmented data for training of the model

# %%
import keras
from keras.models import Sequential
from keras.layers import Conv2D, Dense, Flatten, MaxPooling2D, Dropout

# %%
initial_learning_rate = 0.0001

opt = tf.keras.optimizers.Adam(learning_rate=initial_learning_rate)

# %%
a = int(len(images_train_augmented)-(0.2*len(images_train_augmented)))
a
# Out:
# 608000

# %%
val_img_aug, val_lbl_aug = images_train_augmented[a:], labels_train_augmented[a:]

images_train_augmented, labels_train_augmented = images_train_augmented[:a], labels_train_augmented[:a]

# %%
print(images_train_augmented.shape)
print(val_img_aug.shape)
# Out:
# (320000, 28, 28)
# (80000, 28, 28)

# %% [markdown]
# ### Define a new model

# %% [markdown]
# We were using quite some feature reducing layers with only one interpretation layer. In practice, one convolutional layer with pooling might be enough and it is better to introduce more fully connected layers instead

# %% [markdown]
# We can also add a BatchNormalisation layer before activation functions in attempt to improve accuracy a bit more

# %%
from keras.layers import BatchNormalization, Activation

# %%
model_cnn_v2 = tf.keras.models.Sequential()

# %%
# dropout regularisation layer
model_cnn_v2.add(Dropout(rate=0.3, input_shape=(28, 28, 1)))

# feature extraction layers


model_cnn_v2.add(Conv2D(64, kernel_size=(3,3), padding='same'))
model_cnn_v2.add(BatchNormalization())
model_cnn_v2.add(Activation('relu'))
model_cnn_v2.add(MaxPooling2D((3,3)))

model_cnn_v2.add(Conv2D(8, kernel_size=(3,3), padding='same'))
model_cnn_v2.add(BatchNormalization())
model_cnn_v2.add(Activation('relu'))
model_cnn_v2.add(MaxPooling2D((3,3)))



model_cnn_v2.add(Flatten())

# feature interpretation layers


model_cnn_v2.add(Dense(128))
model_cnn_v2.add(Activation('relu'))
model_cnn_v2.add(Dropout(rate=0.5))

model_cnn_v2.add(Dense(32))
model_cnn_v2.add(Activation('relu'))
model_cnn_v2.add(Dropout(rate=0.2))

# classification layer
model_cnn_v2.add(Dense(10))

# %%
model_cnn_v2.compile(optimizer=opt,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# Try training it on the augmented data over 100 epochs first

# %%
len(images_train_augmented)

# %%
len(val_img_aug)

# %%
initial_learning_rate = 0.001

opt = tf.keras.optimizers.Adam(learning_rate=initial_learning_rate)

# %%
aug_hist_cnn_v2 = model_cnn_v2.fit(images_train_augmented, labels_train_augmented, validation_data=(val_img_aug, val_lbl_aug), epochs=150, batch_size=256)
# Out:
# Epoch 1/150
# 2375/2375 [==============================] - 15s 5ms/step - loss: 1.6541 - accuracy: 0.3901 - val_loss: 1.3296 - val_accuracy: 0.5341
# Epoch 2/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 1.2095 - accuracy: 0.5446 - val_loss: 1.2346 - val_accuracy: 0.5474
# Epoch 3/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 1.0958 - accuracy: 0.5859 - val_loss: 1.2641 - val_accuracy: 0.5305
# Epoch 4/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 1.0317 - accuracy: 0.6103 - val_loss: 1.1636 - val_accuracy: 0.5629
# Epoch 5/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.9907 - accuracy: 0.6255 - val_loss: 1.0838 - val_accuracy: 0.5933
# Epoch 6/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.9595 - accuracy: 0.6373 - val_loss: 1.0639 - val_accuracy: 0.5985
# Epoch 7/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.9362 - accuracy: 0.6459 - val_loss: 0.9995 - val_accuracy: 0.6227
# Epoch 8/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.9156 - accuracy: 0.6543 - val_loss: 0.9510 - val_accuracy: 0.6407
# Epoch 9/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.9012 - accuracy: 0.6606 - val_loss: 0.9352 - val_accuracy: 0.6403
# Epoch 10/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.8856 - accuracy: 0.6662 - val_loss: 0.9237 - val_accuracy: 0.6494
# Epoch 11/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.8743 - accuracy: 0.6705 - val_loss: 0.9023 - val_accuracy: 0.6497
# Epoch 12/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.8624 - accuracy: 0.6755 - val_loss: 0.9076 - val_accuracy: 0.6482
# Epoch 13/150
# 2375/2375 [==============================] - 11s 4ms/step - loss: 0.8540 - accuracy: 0.6791 - val_loss: 0.8899 - val_accuracy: 0.6525
# Epoch 14/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.8437 - accuracy: 0.6826 - val_loss: 0.9261 - val_accuracy: 0.6358
# Epoch 15/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.8343 - accuracy: 0.6863 - val_loss: 0.8981 - val_accuracy: 0.6492
# Epoch 16/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.8280 - accuracy: 0.6894 - val_loss: 0.8860 - val_accuracy: 0.6529
# Epoch 17/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.8204 - accuracy: 0.6923 - val_loss: 0.8969 - val_accuracy: 0.6508
# Epoch 18/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.8158 - accuracy: 0.6947 - val_loss: 0.8383 - val_accuracy: 0.6772
# Epoch 19/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.8094 - accuracy: 0.6971 - val_loss: 0.8871 - val_accuracy: 0.6561
# Epoch 20/150
# 2375/2375 [==============================] - 11s 4ms/step - loss: 0.8038 - accuracy: 0.6991 - val_loss: 0.8670 - val_accuracy: 0.6638
# Epoch 21/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7986 - accuracy: 0.7014 - val_loss: 0.8711 - val_accuracy: 0.6641
# Epoch 22/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7945 - accuracy: 0.7033 - val_loss: 0.8316 - val_accuracy: 0.6777
# Epoch 23/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7902 - accuracy: 0.7046 - val_loss: 0.8427 - val_accuracy: 0.6755
# Epoch 24/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7859 - accuracy: 0.7068 - val_loss: 0.8988 - val_accuracy: 0.6488
# Epoch 25/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7818 - accuracy: 0.7088 - val_loss: 0.8599 - val_accuracy: 0.6662
# Epoch 26/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7767 - accuracy: 0.7111 - val_loss: 0.9438 - val_accuracy: 0.6367
# Epoch 27/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7754 - accuracy: 0.7115 - val_loss: 0.8568 - val_accuracy: 0.6696
# Epoch 28/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7712 - accuracy: 0.7128 - val_loss: 0.8616 - val_accuracy: 0.6673
# Epoch 29/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7680 - accuracy: 0.7133 - val_loss: 0.8795 - val_accuracy: 0.6608
# Epoch 30/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7641 - accuracy: 0.7156 - val_loss: 0.8539 - val_accuracy: 0.6692
# Epoch 31/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7620 - accuracy: 0.7162 - val_loss: 0.8151 - val_accuracy: 0.6864
# Epoch 32/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7594 - accuracy: 0.7172 - val_loss: 0.7934 - val_accuracy: 0.6951
# Epoch 33/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7559 - accuracy: 0.7184 - val_loss: 0.8055 - val_accuracy: 0.6925
# Epoch 34/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7532 - accuracy: 0.7198 - val_loss: 0.8305 - val_accuracy: 0.6809
# Epoch 35/150
# 2375/2375 [==============================] - 11s 4ms/step - loss: 0.7500 - accuracy: 0.7212 - val_loss: 0.8472 - val_accuracy: 0.6682
# Epoch 36/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7482 - accuracy: 0.7222 - val_loss: 0.7991 - val_accuracy: 0.6925
# Epoch 37/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7462 - accuracy: 0.7229 - val_loss: 0.7549 - val_accuracy: 0.7129
# Epoch 38/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7446 - accuracy: 0.7237 - val_loss: 0.7793 - val_accuracy: 0.7033
# Epoch 39/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7423 - accuracy: 0.7245 - val_loss: 0.8048 - val_accuracy: 0.6891
# Epoch 40/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7399 - accuracy: 0.7257 - val_loss: 0.7526 - val_accuracy: 0.7132
# Epoch 41/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7378 - accuracy: 0.7261 - val_loss: 0.8229 - val_accuracy: 0.6821
# Epoch 42/150
# 2375/2375 [==============================] - 11s 4ms/step - loss: 0.7348 - accuracy: 0.7277 - val_loss: 0.7984 - val_accuracy: 0.6920
# Epoch 43/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7337 - accuracy: 0.7279 - val_loss: 0.7894 - val_accuracy: 0.6970
# Epoch 44/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7324 - accuracy: 0.7287 - val_loss: 0.8392 - val_accuracy: 0.6767
# Epoch 45/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7297 - accuracy: 0.7296 - val_loss: 0.7409 - val_accuracy: 0.7187
# Epoch 46/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7275 - accuracy: 0.7305 - val_loss: 0.7295 - val_accuracy: 0.7215
# Epoch 47/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7269 - accuracy: 0.7308 - val_loss: 0.7676 - val_accuracy: 0.7064
# Epoch 48/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7246 - accuracy: 0.7324 - val_loss: 0.7422 - val_accuracy: 0.7158
# Epoch 49/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7218 - accuracy: 0.7328 - val_loss: 0.7520 - val_accuracy: 0.7127
# Epoch 50/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7221 - accuracy: 0.7331 - val_loss: 0.7243 - val_accuracy: 0.7235
# Epoch 51/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7194 - accuracy: 0.7341 - val_loss: 0.7342 - val_accuracy: 0.7208
# Epoch 52/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7172 - accuracy: 0.7347 - val_loss: 0.7180 - val_accuracy: 0.7270
# Epoch 53/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7166 - accuracy: 0.7358 - val_loss: 0.7218 - val_accuracy: 0.7273
# Epoch 54/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7149 - accuracy: 0.7363 - val_loss: 0.7432 - val_accuracy: 0.7190
# Epoch 55/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7141 - accuracy: 0.7362 - val_loss: 0.7134 - val_accuracy: 0.7289
# Epoch 56/150
# 2375/2375 [==============================] - 10s 4ms/step - loss: 0.7134 - accuracy: 0.7371 - val_loss: 0.7375 - val_accuracy: 0.7195
# Epoch 57/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7111 - accuracy: 0.7372 - val_loss: 0.7524 - val_accuracy: 0.7121
# Epoch 58/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7102 - accuracy: 0.7382 - val_loss: 0.7446 - val_accuracy: 0.7108
# Epoch 59/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7089 - accuracy: 0.7382 - val_loss: 0.7037 - val_accuracy: 0.7331
# Epoch 60/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7085 - accuracy: 0.7388 - val_loss: 0.7349 - val_accuracy: 0.7189
# Epoch 61/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7067 - accuracy: 0.7398 - val_loss: 0.7170 - val_accuracy: 0.7252
# Epoch 62/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7056 - accuracy: 0.7407 - val_loss: 0.7250 - val_accuracy: 0.7203
# Epoch 63/150
# 2375/2375 [==============================] - 11s 4ms/step - loss: 0.7055 - accuracy: 0.7408 - val_loss: 0.7528 - val_accuracy: 0.7099
# Epoch 64/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7032 - accuracy: 0.7409 - val_loss: 0.6954 - val_accuracy: 0.7367
# Epoch 65/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7026 - accuracy: 0.7418 - val_loss: 0.6925 - val_accuracy: 0.7367
# Epoch 66/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7002 - accuracy: 0.7426 - val_loss: 0.6812 - val_accuracy: 0.7412
# Epoch 67/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.7006 - accuracy: 0.7422 - val_loss: 0.7182 - val_accuracy: 0.7264
# Epoch 68/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6980 - accuracy: 0.7438 - val_loss: 0.7128 - val_accuracy: 0.7260
# Epoch 69/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6980 - accuracy: 0.7436 - val_loss: 0.7120 - val_accuracy: 0.7259
# Epoch 70/150
# 2375/2375 [==============================] - 11s 4ms/step - loss: 0.6982 - accuracy: 0.7438 - val_loss: 0.7182 - val_accuracy: 0.7262
# Epoch 71/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6954 - accuracy: 0.7437 - val_loss: 0.6976 - val_accuracy: 0.7331
# Epoch 72/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6953 - accuracy: 0.7447 - val_loss: 0.6904 - val_accuracy: 0.7371
# Epoch 73/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6940 - accuracy: 0.7451 - val_loss: 0.6911 - val_accuracy: 0.7361
# Epoch 74/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6938 - accuracy: 0.7455 - val_loss: 0.6991 - val_accuracy: 0.7312
# Epoch 75/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6920 - accuracy: 0.7458 - val_loss: 0.6663 - val_accuracy: 0.7476
# Epoch 76/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6918 - accuracy: 0.7465 - val_loss: 0.7096 - val_accuracy: 0.7282
# Epoch 77/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6901 - accuracy: 0.7468 - val_loss: 0.6888 - val_accuracy: 0.7364
# Epoch 78/150
# 2375/2375 [==============================] - 11s 4ms/step - loss: 0.6893 - accuracy: 0.7472 - val_loss: 0.6737 - val_accuracy: 0.7444
# Epoch 79/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6888 - accuracy: 0.7473 - val_loss: 0.7032 - val_accuracy: 0.7292
# Epoch 80/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6886 - accuracy: 0.7470 - val_loss: 0.6891 - val_accuracy: 0.7372
# Epoch 81/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6873 - accuracy: 0.7482 - val_loss: 0.6754 - val_accuracy: 0.7431
# Epoch 82/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6858 - accuracy: 0.7486 - val_loss: 0.6800 - val_accuracy: 0.7407
# Epoch 83/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6856 - accuracy: 0.7488 - val_loss: 0.6912 - val_accuracy: 0.7376
# Epoch 84/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6848 - accuracy: 0.7487 - val_loss: 0.6732 - val_accuracy: 0.7428
# Epoch 85/150
# 2375/2375 [==============================] - 11s 4ms/step - loss: 0.6845 - accuracy: 0.7493 - val_loss: 0.6632 - val_accuracy: 0.7485
# Epoch 86/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6822 - accuracy: 0.7498 - val_loss: 0.6625 - val_accuracy: 0.7489
# Epoch 87/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6842 - accuracy: 0.7497 - val_loss: 0.6640 - val_accuracy: 0.7479
# Epoch 88/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6820 - accuracy: 0.7503 - val_loss: 0.6843 - val_accuracy: 0.7382
# Epoch 89/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6816 - accuracy: 0.7505 - val_loss: 0.6836 - val_accuracy: 0.7389
# Epoch 90/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6812 - accuracy: 0.7509 - val_loss: 0.6770 - val_accuracy: 0.7401
# Epoch 91/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6796 - accuracy: 0.7513 - val_loss: 0.6749 - val_accuracy: 0.7402
# Epoch 92/150
# 2375/2375 [==============================] - 11s 4ms/step - loss: 0.6789 - accuracy: 0.7515 - val_loss: 0.6711 - val_accuracy: 0.7428
# Epoch 93/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6779 - accuracy: 0.7519 - val_loss: 0.6473 - val_accuracy: 0.7541
# Epoch 94/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6776 - accuracy: 0.7525 - val_loss: 0.7196 - val_accuracy: 0.7211
# Epoch 95/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6790 - accuracy: 0.7519 - val_loss: 0.6705 - val_accuracy: 0.7449
# Epoch 96/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6760 - accuracy: 0.7525 - val_loss: 0.6701 - val_accuracy: 0.7446
# Epoch 97/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6771 - accuracy: 0.7522 - val_loss: 0.6599 - val_accuracy: 0.7491
# Epoch 98/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6759 - accuracy: 0.7525 - val_loss: 0.6588 - val_accuracy: 0.7493
# Epoch 99/150
# 2375/2375 [==============================] - 11s 4ms/step - loss: 0.6766 - accuracy: 0.7521 - val_loss: 0.6485 - val_accuracy: 0.7528
# Epoch 100/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6759 - accuracy: 0.7534 - val_loss: 0.6362 - val_accuracy: 0.7584
# Epoch 101/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6750 - accuracy: 0.7529 - val_loss: 0.6434 - val_accuracy: 0.7546
# Epoch 102/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6750 - accuracy: 0.7538 - val_loss: 0.6573 - val_accuracy: 0.7502
# Epoch 103/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6722 - accuracy: 0.7541 - val_loss: 0.6419 - val_accuracy: 0.7556
# Epoch 104/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6729 - accuracy: 0.7540 - val_loss: 0.6508 - val_accuracy: 0.7525
# Epoch 105/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6722 - accuracy: 0.7540 - val_loss: 0.6540 - val_accuracy: 0.7509
# Epoch 106/150
# 2375/2375 [==============================] - 11s 4ms/step - loss: 0.6719 - accuracy: 0.7544 - val_loss: 0.6447 - val_accuracy: 0.7546
# Epoch 107/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6714 - accuracy: 0.7544 - val_loss: 0.6395 - val_accuracy: 0.7587
# Epoch 108/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6714 - accuracy: 0.7550 - val_loss: 0.6357 - val_accuracy: 0.7580
# Epoch 109/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6712 - accuracy: 0.7549 - val_loss: 0.6245 - val_accuracy: 0.7643
# Epoch 110/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6713 - accuracy: 0.7546 - val_loss: 0.6695 - val_accuracy: 0.7425
# Epoch 111/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6685 - accuracy: 0.7561 - val_loss: 0.6363 - val_accuracy: 0.7576
# Epoch 112/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6707 - accuracy: 0.7554 - val_loss: 0.6261 - val_accuracy: 0.7641
# Epoch 113/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6690 - accuracy: 0.7555 - val_loss: 0.6479 - val_accuracy: 0.7536
# Epoch 114/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6676 - accuracy: 0.7562 - val_loss: 0.6317 - val_accuracy: 0.7604
# Epoch 115/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6683 - accuracy: 0.7564 - val_loss: 0.6469 - val_accuracy: 0.7515
# Epoch 116/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6676 - accuracy: 0.7563 - val_loss: 0.6271 - val_accuracy: 0.7607
# Epoch 117/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6664 - accuracy: 0.7572 - val_loss: 0.6627 - val_accuracy: 0.7462
# Epoch 118/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6671 - accuracy: 0.7569 - val_loss: 0.6302 - val_accuracy: 0.7615
# Epoch 119/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6653 - accuracy: 0.7571 - val_loss: 0.6592 - val_accuracy: 0.7476
# Epoch 120/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6669 - accuracy: 0.7568 - val_loss: 0.6397 - val_accuracy: 0.7569
# Epoch 121/150
# 2375/2375 [==============================] - 11s 4ms/step - loss: 0.6664 - accuracy: 0.7567 - val_loss: 0.6386 - val_accuracy: 0.7562
# Epoch 122/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6645 - accuracy: 0.7577 - val_loss: 0.6395 - val_accuracy: 0.7564
# Epoch 123/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6640 - accuracy: 0.7575 - val_loss: 0.6285 - val_accuracy: 0.7606
# Epoch 124/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6640 - accuracy: 0.7578 - val_loss: 0.6777 - val_accuracy: 0.7386
# Epoch 125/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6649 - accuracy: 0.7576 - val_loss: 0.6300 - val_accuracy: 0.7608
# Epoch 126/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6627 - accuracy: 0.7583 - val_loss: 0.6475 - val_accuracy: 0.7522
# Epoch 127/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6638 - accuracy: 0.7581 - val_loss: 0.6409 - val_accuracy: 0.7558
# Epoch 128/150
# 2375/2375 [==============================] - 11s 4ms/step - loss: 0.6625 - accuracy: 0.7580 - val_loss: 0.6243 - val_accuracy: 0.7630
# Epoch 129/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6632 - accuracy: 0.7584 - val_loss: 0.6259 - val_accuracy: 0.7621
# Epoch 130/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6621 - accuracy: 0.7593 - val_loss: 0.6296 - val_accuracy: 0.7603
# Epoch 131/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6635 - accuracy: 0.7582 - val_loss: 0.6443 - val_accuracy: 0.7536
# Epoch 132/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6614 - accuracy: 0.7600 - val_loss: 0.6224 - val_accuracy: 0.7654
# Epoch 133/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6613 - accuracy: 0.7591 - val_loss: 0.6376 - val_accuracy: 0.7569
# Epoch 134/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6611 - accuracy: 0.7594 - val_loss: 0.6227 - val_accuracy: 0.7629
# Epoch 135/150
# 2375/2375 [==============================] - 11s 4ms/step - loss: 0.6600 - accuracy: 0.7597 - val_loss: 0.6309 - val_accuracy: 0.7595
# Epoch 136/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6609 - accuracy: 0.7591 - val_loss: 0.6321 - val_accuracy: 0.7588
# Epoch 137/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6591 - accuracy: 0.7602 - val_loss: 0.6157 - val_accuracy: 0.7674
# Epoch 138/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6600 - accuracy: 0.7595 - val_loss: 0.6194 - val_accuracy: 0.7646
# Epoch 139/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6595 - accuracy: 0.7595 - val_loss: 0.6407 - val_accuracy: 0.7539
# Epoch 140/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6583 - accuracy: 0.7598 - val_loss: 0.6221 - val_accuracy: 0.7637
# Epoch 141/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6594 - accuracy: 0.7598 - val_loss: 0.6337 - val_accuracy: 0.7573
# Epoch 142/150
# 2375/2375 [==============================] - 11s 4ms/step - loss: 0.6591 - accuracy: 0.7594 - val_loss: 0.6137 - val_accuracy: 0.7666
# Epoch 143/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6584 - accuracy: 0.7599 - val_loss: 0.6331 - val_accuracy: 0.7582
# Epoch 144/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6583 - accuracy: 0.7604 - val_loss: 0.6142 - val_accuracy: 0.7672
# Epoch 145/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6576 - accuracy: 0.7599 - val_loss: 0.6209 - val_accuracy: 0.7643
# Epoch 146/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6567 - accuracy: 0.7610 - val_loss: 0.6459 - val_accuracy: 0.7521
# Epoch 147/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6561 - accuracy: 0.7609 - val_loss: 0.6365 - val_accuracy: 0.7542
# Epoch 148/150
# 2375/2375 [==============================] - 11s 5ms/step - loss: 0.6570 - accuracy: 0.7612 - val_loss: 0.6314 - val_accuracy: 0.7589
# Epoch 149/150
# 2375/2375 [==============================] - 11s 4ms/step - loss: 0.6570 - accuracy: 0.7611 - val_loss: 0.6127 - val_accuracy: 0.7682
# Epoch 150/150
# 2375/2375 [==============================] - 11s 4ms/step - loss: 0.6559 - accuracy: 0.7606 - val_loss: 0.6330 - val_accuracy: 0.7562

# %%
fig2 = plt.figure(figsize = (10,4))

ax4 = fig2.add_subplot(121)

ax4.plot(aug_hist_cnn_v2.history['loss'], color='red', label='training loss v2 (aug)')
ax4.plot(aug_hist_cnn_v2.history['val_loss'], color='green', label='validation loss v2 (aug)')
ax4.set_title('Loss', fontsize=20)
ax4.set_ylim(bottom=0)
ax4.legend(loc="best")

ax5 = fig2.add_subplot(122)
ax5.plot(aug_hist_cnn_v2.history['accuracy'], color='red', label='training accuracy v2 (aug)')
ax5.plot(aug_hist_cnn_v2.history['val_accuracy'], color='green', label='validation accuracy v2 (aug)')
ax5.set_title('Accuracy', fontsize=20)
ax5.legend(loc="best")

plt.show()
